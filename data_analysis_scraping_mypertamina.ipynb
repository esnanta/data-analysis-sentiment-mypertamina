# %%
# !pip install google-play-scraper
from google_play_scraper import app, reviews, Sort, reviews_all
from google.colab import files
import pandas as pd

csv_filename = "mypertamina_reviews.csv"
scrapreview = reviews (         # reviews_all() maka parameter count tidak akan bekerja dengan baik.
    'com.dafturn.mypertamina',  # ID aplikasi
    lang='id',                  # Bahasa ulasan
    country='id',               # Negara
    sort=Sort.MOST_RELEVANT,    # Urutan ulasan
    count=10000                 # Maksimum jumlah ulasan yang diambil
)

# Konversi hasil scraping ke DataFrame
reviews_df = pd.DataFrame(scrapreview)
reviews_df.to_csv(csv_filename, index=False, encoding="utf-8")
files.download('mypertamina_reviews.csv')

reviews_df.info()
reviews_df.head()
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146629 entries, 0 to 146628
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              146629 non-null  object
#  1   userName              146629 non-null  object
#  2   userImage             146629 non-null  object
#  3   content               146629 non-null  object
#  4   score                 146629 non-null  int64
#  5   thumbsUpCount         146629 non-null  int64
#  6   reviewCreatedVersion  121854 non-null  object
#  7   at                    146629 non-null  datetime64[ns]
#  8   replyContent          17777 non-null   object
#  9   repliedAt             17777 non-null   datetime64[ns]
#  10  appVersion            121854 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 12.3+ MB
#                                reviewId         userName  \
# 0  8eb604e7-6b35-4c77-9a01-7da325e46204  Pengguna Google
# 1  a4994116-a3c1-4a46-9001-1bfdfa10b9a2  Pengguna Google
# 2  46e5bca6-88fb-4b2a-98aa-03a815d8f7a9  Pengguna Google
# 3  b2e0aacc-4222-446b-aa61-dc3b8e850fde  Pengguna Google
# 4  bda93d55-5a29-4807-abda-121993dea84e  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasi yang sangat buruk,isi data berlapis, ...      1             34
# 1  Tadinya sdh bisa registrasi mypertamina dan sd...      1             98
# 2  Makin kesini makin di persulit, mulai dari sud...      1             24
# 3  ambil foto nge blur terus heran, pdhal kamera ...      1              3
# 4  Aplikasinya sangat mempersulit untuk fitur fot...      1              2
#
#   reviewCreatedVersion                  at  \
# 0                4.6.6 2025-02-10 23:53:44
# 1                4.6.6 2025-02-01 05:17:32
# 2                4.6.6 2025-02-08 21:37:29
# 3                4.6.6 2025-02-14 13:27:04
# 4                4.6.6 2025-02-15 01:44:20
#
#                                         replyContent           repliedAt  \
# 0  Hai, Sobat. Mimin sampaikan, mengambil foto ST... 2025-02-11 11:02:12
# 1  Hai, Sobat Zen. Mohon maaf atas ketidaknyamana... 2025-02-01 08:25:03
# 2  Hai, Sobat Julia. Mohon maaf atas ketidaknyama... 2025-02-09 08:37:36
# 3  Hai, Sobat Yanti. Mohon maaf atas ketidaknyama... 2025-02-15 09:35:06
# 4  Hai, Sobat Cahyaning. Mimin bantu sampaikan pr... 2025-02-15 09:21:49
#
#   appVersion
# 0      4.6.6
# 1      4.6.6
# 2      4.6.6
# 3      4.6.6
# 4      4.6.6
